# %% [markdown]
# # Chess Endgame Classification - Google Colab Training
#
# This notebook provides GPU-accelerated training for the chess endgame classifier.
#
# ## Setup
# 1. Upload your project files to Colab
# 2. Run all cells
# 3. Training will use GPU automatically

# %%
# Check GPU availability
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
else:
    print("No GPU detected - using CPU (slower)")

# %%
# Install dependencies
# !pip install torch torchvision numpy pandas scikit-learn python-chess matplotlib seaborn tqdm

# %%
# Upload your files (run this cell and upload your project files)
from google.colab import files
import zipfile
import os

print("Please upload your project zip file:")
uploaded = files.upload()

# Extract files
for filename in uploaded.keys():
    if filename.endswith('.zip'):
        with zipfile.ZipFile(filename, 'r') as zip_ref:
            zip_ref.extractall('.')
        print(f"Extracted {filename}")
        break

# %%
# Check if dataset exists
import os
if os.path.exists('data/generated_data.csv'):
    print("✅ Dataset found")
    import pandas as pd
    df = pd.read_csv('data/generated_data.csv')
    print(f"Dataset size: {len(df)}")
else:
    print("❌ Dataset not found. Please generate it first:")
    print("python src/generate\\ data/generate_dataset.py")

# %%
# Quick test training (small dataset, few epochs)
# !python main.py train --csv-path data/generated_data.csv --save-dir checkpoints --epochs 5 --quick-test

# %%
# Full training (use this after quick test works)
# !python main.py train --csv-path data/generated_data.csv --save-dir checkpoints --epochs 50

# %%
# Download trained model
from google.colab import files
import os

if os.path.exists('checkpoints/final_model.pth'):
    files.download('checkpoints/final_model.pth')
    print("✅ Model downloaded")
    
if os.path.exists('checkpoints/encoders.pkl'):
    files.download('checkpoints/encoders.pkl')
    print("✅ Encoders downloaded")
else:
    print("❌ No trained model found")
