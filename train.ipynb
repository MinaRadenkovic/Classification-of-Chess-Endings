# %%
import torch
from main import train_model   # ako ti se fajl zove main.py

class Args:
    command = "train"
    csv_path = "data/generated_data.csv"
    save_dir = "checkpoints"
    batch_size = 128
    epochs = 50
    max_samples = None
    device = "cuda"
    num_workers = 2
    train_ratio = 0.7
    val_ratio = 0.15
    test_ratio = 0.15
    normalize = False
    add_turn_channel = True
    save_every = 10
    early_stopping_patience = 10

args = Args()

print("Using device:", args.device)
train_model(args)
